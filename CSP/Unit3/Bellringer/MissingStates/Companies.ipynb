# %%
import pandas as pd

# %%
#grabs the header of the file
data = pd.read_csv("MOCK_DATA.csv",header=0)

#grabs unique companies and makes it a list
company = data.company.unique()

# %%
dir={}

#puts all companys and the cost into a directory
for i in company:
    dir[i] = 0

#grabs all of the instances of the companys and cost then put it in a list
data1=data["company"]
data2=data["cost"]

# %%
#adds up all the cost for the unique company
for i in range(len(data1)):
    dir[data1[i]] = dir[data1[i]] + data2[i]
print(dir)
print(len(dir))
# Out:
# {'Skidoo': 207726.74000000002, 'Twitterwire': 343342.81999999995, 'Oyoba': 213001.37999999998, 'Aimbo': 169160.38000000003, 'Shuffledrive': 208764.28000000003, 'Fiveclub': 281702.33999999997, 'Eire': 178055.1, 'Linkbuzz': 208164.12000000002, 'Youtags': 203718.97999999998, 'Meetz': 191176.50000000003, 'Flashpoint': 213794.15999999997, 'Roomm': 223432.82, 'Edgeblab': 228534.34000000003, 'Skippad': 251570.97999999998, 'Eadel': 181961.14, 'Zava': 340336.23999999993, 'Gabtune': 156569.02000000002, 'Brainlounge': 157371.20000000004, 'Gabcube': 209233.62, 'Fivebridge': 194029.64000000004, 'Realbridge': 158714.62, 'Gabtype': 257239.96000000002, 'Voolith': 224292.5599999999, 'Quatz': 534805.0400000003, 'Kare': 213832.78000000003, 'Mudo': 271037.83999999997, 'Browsebug': 175420.54000000004, 'Devpoint': 231551.60000000003, 'Quaxo': 252381.27999999997, 'Avamm': 210394.63999999998, 'Fatz': 160521.84000000003, 'Dynava': 204983.74000000002, 'Latz': 206285.33999999997, 'Babbleopia': 205697.18000000002, 'Tagpad': 284318.7, 'Tavu': 264220.9399999999, 'Kanoodle': 214944.00000000003, 'Kimia': 200520.37999999998, 'Linklinks': 342028.12, 'Flashset': 274520.56, 'Zoomcast': 419620.5, 'Rhynoodle': 148554.88, 'Skaboo': 211984.72000000003, 'Zoomzone': 138513.76, 'Fivespan': 282402.74, 'Devbug': 178927.28000000003, 'Jatri': 215996.96000000002, 'Meevee': 448319.8600000001, 'Feedmix': 270125.4, 'Topiczoom': 192704.74000000005, 'Browsezoom': 286950.7199999999, 'Quinu': 432787.0400000001, 'Camimbo': 138986.84, 'Eamia': 164017.7, 'Realblab': 344396.52, 'Jaxbean': 290323.04, 'Voomm': 466560.14, 'JumpXS': 236870.6799999999, 'Plajo': 322504.79999999993, 'Vimbo': 249896.06000000008, 'Mycat': 206584.33999999997, 'LiveZ': 245692.26000000004, 'Brightbean': 264602.81999999995, 'Jetpulse': 276560.42, 'Photolist': 195065.17999999996, 'Thoughtstorm': 370436.0, 'Jazzy': 215474.77999999997, 'Devpulse': 229085.02, 'Skiptube': 314676.34000000014, 'Topicware': 230841.75999999998, 'Browseblab': 267989.42, 'Centidel': 277431.83999999997, 'Centizu': 264132.02, 'Shuffletag': 233653.62000000005, 'Digitube': 191075.00000000006, 'Thoughtbridge': 290293.6999999999, 'Skyble': 239345.66000000003, 'Tanoodle': 323451.25999999995, 'Dynabox': 632517.8600000002, 'Browsetype': 167593.24000000002, 'Tagchat': 291844.98, 'Yakitri': 200515.38, 'Divape': 215989.91999999995, 'Yabox': 179052.92, 'Npath': 228836.06000000003, 'Wordpedia': 333233.26, 'Miboo': 308399.2, 'Twimbo': 295099.16, 'Trudoo': 334953.9599999999, 'Izio': 239009.25999999995, 'Yombu': 266399.51999999996, 'Vitz': 222046.24000000005, 'Jabberbean': 253918.61999999997, 'Voonder': 174684.34000000003, 'Topicblab': 300491.67999999993, 'Yakijo': 251621.24000000005, 'Skyndu': 272174.45999999996, 'Tazzy': 175583.56, 'Blogpad': 248428.25999999998, 'Avaveo': 265318.42000000004, 'Rhyzio': 305744.7600000001, 'Buzzbean': 231093.26000000004, 'Photobug': 415364.86000000016, 'Jaxworks': 138908.4, 'Jabbersphere': 547226.62, 'Jayo': 495855.56, 'Skimia': 359361.5599999999, 'Lajo': 227865.03999999995, 'Blognation': 222588.55999999994, 'Rhyloo': 179264.94000000003, 'Mynte': 413854.3600000002, 'Midel': 299288.12, 'Tekfly': 144610.18000000002, 'Gabspot': 196412.74000000005, 'Linkbridge': 175909.13999999998, 'Layo': 274019.94, 'Skinder': 281264.07999999996, 'Rooxo': 169758.40000000005, 'Jetwire': 238091.19999999995, 'Roodel': 214160.96000000005, 'Buzzshare': 235680.44000000003, 'Leexo': 278874.12000000005, 'Tagopia': 296459.86, 'Zooxo': 181701.52000000002, 'Tagcat': 201628.24, 'Riffpath': 245709.32000000004, 'Trupe': 165376.34, 'Yambee': 194927.65999999997, 'Yodo': 344713.12000000005, 'Jaloo': 251076.38, 'Oba': 229138.32000000004, 'Zoombeat': 167035.08000000005, 'Viva': 154658.87999999998, 'Voonix': 161118.26, 'Avamba': 238543.31999999998, 'Yamia': 165147.80000000005, 'Skyvu': 249966.33999999997, 'Kwideo': 276789.5, 'Skilith': 274157.93999999994, 'Gabvine': 198695.37999999992, 'Chatterpoint': 229796.87999999995, 'Flipstorm': 194865.11999999997, 'Kaymbo': 3 ...
# 1352

# %%
total=0
#adds up the total cost of all compaines
for i in data2:
    total+=i
print(round(total))
# Out:
# 46204383
